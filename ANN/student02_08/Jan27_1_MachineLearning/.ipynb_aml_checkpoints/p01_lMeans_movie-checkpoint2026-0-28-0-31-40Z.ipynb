# %%
# 분류 (classfication) : 지도학습
#   학습하고 나서
#   70, 30은 뭐게 -> 액션
#   미지의 데이터에 대한 결과 예측

# 군집화 (clustering) : 비지도학습
#   데이터 넣어주고
#   비슷한것끼리 묶어봐라

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.DataFrame()
df["fight"] = [80,95,10,90,5]
df["yok"] =   [20,5, 90,10,95]

print(df)
sns.scatterplot(df,x="fight",y="yok")
plt.show()
# Out:
#    fight  yok
# 0     80   20
# 1     95    5
# 2     10   90
# 3     90   10
# 4      5   95

# %%
# kMeans : k개의 평균들
#   군집화
#   k=2로 했다치면 
#   1) 데이터들 그래프에 표시
#   2) 랜덤한 점 2개를 그래프에 표시
#   3) 2번에서 찍은 점과 데이터들간의 거리 계산
#   4) 가까운쪽으로 그룹화
#   5) 그룹 내에서 평균내서 그 위치에 점 찍고
#   6) 5번에서 찍은 점과 데이터들간의 거리 계산
#   7) 가까운쪽으로 그룹화

from sklearn.cluster import KMeans

data = df[['fight','yok']].to_numpy()

km = KMeans(2)   #2개의 군집화

print(km.fit_predict(data))  # 0번군집과 1번군집

df["group"]=km.fit_predict(data)

sns.scatterplot(df,x="fight",y="yok",palette="rainbow", hue="group")
# Out:
# [1 1 0 1 0]
# <Axes: xlabel='fight', ylabel='yok'>
