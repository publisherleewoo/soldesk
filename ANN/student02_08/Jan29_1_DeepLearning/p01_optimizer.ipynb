# %%
# GradientDescent 
#       L = e1 + e1 + e3 + ... + e1000000  (L = Loss Function)
#       모든 데이터를 다 고려하니 -> 느림
#       local minimum

# SGD(Stochastic GD)
#       e1, e2, e3, ..., e100000
#       중에서 랜덤하게 1개만 빼서 L로
#       나머지 중에서 랜덤하게 1개만 빼서 L로
#       ... 반복
#       의외성 생겨서 다른 웅덩이에 빠질 수 있음(local minimum 해결 가능)
#       오차 하나만 보니까 빠름

# mini-batch SGD
#       100만 개의 데이터를 다 계산해서 더한 전체 오차
#       하나만 보지 말고 몇개씩 보는기 때문에 상대적으로 SGD보다 정확도가 높으나 느림
#       눈이 아주 좋은 사람이 산 정상에서 아래를 다 내려다보며 가장 낮은 골짜기로 천천히 내려가는 것.
#
# momentum 
#       그 전단계의 Gradient값을 추가로 넣어서 : 관성
#       -> 움직이는 값이 줄고
#       -> 직교x, 더 다이렉트하게 최적의 값을 향해
# 
# RMSProp(Root Mean Squared Propagation)
#       x, y 각각 누적된 G값으로 나눠서 -> x,y를 동등하게 해서 의외성을 노려보자

# Adam




# 정리.  SGD는 단일 직렬 느낌이면,  mini-batch SGD는 병렬 느낌

# parameter : AI가 찾아 내야 하는 변수
#   Weight,bias

# hyperParameter : 사람이 지정해줘야하는 변수
#   learning rate : GD갈때 얼마씩 가는지
#   batch size : 데이터를 몇개 씩 볼건지

#       Q. 만약 mini-batch SGD에서 e1, e2, e3, ..., e100000 데이터에서 batch size =100000 지정하면 GD?
#       A. 아무리 GPU가 있어도 동시에 1000만개는 불가

#   epoch : 전체 데이터 다 보는걸 몇번 반복
