# %%
# acttivation(활성화 함수)
#   Linear Activation : 들어오는 값 그대로 나가게 = 아무것도 안한다
#   USF(Unit Step Function) : 음수 들어오면 0, 양수들어오면 1
#                              너무 빡빡
#                               0부분에 잘려있어서 극한값 없 - > GD 불가
#   sigmoid : 1 / (1 + (e ** -x))
#       비분해서 기울기가 나올수있는게 1/4
#       역전파가 진행되어서 1/4 * 1/4 * 1/4 * ... = 0에 가깝게
#   vanishing gradient
#       -> 앞층으로 갈수록 G값이 거의 0 -> 대세에 영향을 거의 못줌
#   ReLu(Rectified Linear Unit)
#       입력값이 0보다 크면 그 값을 그대로 출력
#       입력값이 0보다 작거나 같으면 무조건 0을 출력
#
# Non-linear Activation 필요한 이유(=활성화 함수가 필요한 이유)
# y = (x * W1 + b1) * W2 + b2
#   = (x * (W1 * W2)) + ((b1 * W2) + b2)
#           2x3  3x2     1x3  3x2   1x2
#   = (x * W?) + b?
#          2x2  1x2

#   ->3층짜리 DNN을 구성했는데 결과가 ANN과 같아져버림
