# %%
# 1 2
# 3 4
# 5 6
# (3X2)

# 행렬 덧셈 : 같은 자리에 있는것끼리 더하기 -> 두 행렬 모양이 같아야, 결과는 그 모양

# [[1,2]    10 20     1+20  2+20     [[11,22]
# [3,4]   + 30 40  =  3+30  4+40  =   [33,44]
# [5,6]]    50 60     5+50  6+60      [55,66]]
# (3x2)     (3x2)                      (3x2)


# 행렬 곱셈(Matrix Multiplication)
# -> (axb) *(cxd) 라면?, b=c 같아야 계산가능, 결과는 (axd)
# [[1,2]   10 20   1*10+2*30   1*20+2*40   [[70,100]
#  [3,4] * 30 40 = 3*10+4*30   3*20+4*40  = [150,220]
#  [5,6]]          5*10+6*30   5*20+6*40    [230,340]
#  (3x2)   (2x2)
