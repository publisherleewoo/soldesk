# %%
# overfitting
#   보유한 학습데이터에만 너무 딱맞게, 다른 데이터 넣으면 오차 폭발

# data augmentation
#   일부러 학습데이터 변형 가해서(사진이면 뒤집어서, 색 바꿔서, ...)

# dropout : 랜덤하게 노드를 가려가면서 학습
#   첫데이터 통과할때 노드 1/3개 가리고(없는셈치고)
#   두번째 데이터 통과할때 노드 1/3개 가리고(없는셈치고)
#   ...        
# dropconnection : 랜덤하게 연결을 가려가면서 학습
# -> 실 사용할때는 다 살려서
