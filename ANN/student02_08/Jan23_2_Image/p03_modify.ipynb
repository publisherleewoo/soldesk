# %%
import os

# 1. 파일이 있는 실제 경로를 복사해서 넣어주세요
target_path = "/mnt/batch/tasks/shared/LS_root/mounts/clusters/testcom0208/code/Users/student02_08/Jan23_2_Image"

# 2. 해당 경로로 작업 디렉토리 변경
os.chdir(target_path)

# 3. 변경된 경로 확인
print("변경된 현재 경로:", os.getcwd())
# Out:
# 변경된 현재 경로: /mnt/batch/tasks/shared/LS_root/mounts/clusters/testcom0208/code/Users/student02_08/Jan23_2_Image

# %%
import cv2
import matplotlib.pyplot as plt

a = cv2.imread('./android_normal.png', cv2.IMREAD_GRAYSCALE)

print(a)

#인공신경망 =행렬계산 -> 행렬 계산하려면 사이즈가 같아야
# b = a[10:20,3:5] #부문만 잘라 가져오기
# print(b)
# plt.imshow(b)

# c= cv2.resize(a,dsize=(10,20))  # 10x20으로
# print(c)
# plt.imshow(c,cmap='gray' )
# plt.show()

d= cv2.resize(a,dsize=(0,0),fx=0.3, fy=0.3)
print(d)
plt.imshow(d,cmap='gray' )
plt.show()
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# [[255 255 255 255 245 255 255 255 255 255 243 255 255 255 255]
#  [255 255 255 255 255 218 228 217 228 231 255 255 255 255 255]
#  [255 255 255 255 213 158 161 161 161 158 206 255 255 255 255]
#  [255 255 255 234 161 248 158 161 160 250 161 234 255 255 255]
#  [255 255 255 157 161 161 161 161 161 161 161 157 255 255 255]
#  [255 253 255 254 253 252 251 251 251 252 253 254 255 241 255]
#  [230 161 206 157 161 161 161 161 161 161 161 157 215 161 223]
#  [226 161 195 157 161 161 161 161 161 161 161 158 209 161 217]
#  [225 161 195 157 161 161 161 161 161 161 161 158 215 161 217]
#  [226 161 195 157 161 161 161 161 161 161 161 158 217 161 217]
#  [225 161 195 157 161 161 161 161 161 161 161 158 217 161 217]
#  [254 170 250 157 161 161 161 161 161 161 161 158 254 185 254]
#  [255 255 255 157 161 161 161 161 161 161 161 158 255 255 255]
#  [255 255 255 198 177 161 162 177 161 161 174 192 255 255 255]
#  [255 255 255 255 242 161 166 255 169 161 237 255 255 255 255]
#  [255 255 255 255 242 161 166 255 169 161 237 255 255 255 255]
#  [255 255 255 255 255 162 206 255 216 160 252 255 255 255 255]]
