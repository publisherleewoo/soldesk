# %%
# 인공싱경망 : 행렬계산 + 회귀를 통해 최적의 W, b찾는것
# 데이터 : 글자, 숫자, 이미지, 영상, 음성, ...
#   컴은 전자기기 - > 모든 데이터는 전기신호(흐름/안흐름) -> 2진수
#   데이터를 인코딩/디코딩만 가능하다면

# %%
# %pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# ...
# Using cached opencv_python-4.13.0.90-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# 1. 파일이 있는 실제 경로를 복사해서 넣어주세요
target_path = "/mnt/batch/tasks/shared/LS_root/mounts/clusters/testcom0208/code/Users/student02_08/Jan23_2_Image"

# 2. 해당 경로로 작업 디렉토리 변경
os.chdir(target_path)

# 3. 변경된 경로 확인
print("변경된 현재 경로:", os.getcwd())
# Out:
# 변경된 현재 경로: /mnt/batch/tasks/shared/LS_root/mounts/clusters/testcom0208/code/Users/student02_08/Jan23_2_Image

# %%
import cv2


a = cv2.imread("./test.png",cv2.IMREAD_GRAYSCALE) #그레이스케일
print(a)
# Out:
# [[255 255 255 255 255]
#  [255   0   0 255 255]
#  [255   0   0 255 255]
#  [255 255   0   0 255]]

# %%
b =  cv2.imread("./test.png",cv2.IMREAD_COLOR)  #컬러를 살림
print(b)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [  0   0   0]
#   [  0   0   0]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [  0   0   0]
#   [  0   0   0]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [  0   0   0]
#   [  0   0   0]
#   [255 255 255]]]
