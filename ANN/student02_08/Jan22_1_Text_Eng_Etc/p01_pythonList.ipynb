# %%
a = ["ㄱ","ㄴ","ㄷ"]
b = ["ㄹ","ㄴ","ㅁ","ㄷ"]

# %%
for bb in b:
    for aa in a:
        if bb == aa:
            print(bb)
          
print("----")

for bb in b:
    if bb in a :
        print(bb)

c = []
for bb in b :
    c.append(bb)

d =[bb for bb in b]

print(b)
print(c)
print(d)
# Out:
# ㄴ
# ㄷ
# ----
# ㄴ
# ㄷ
# ['ㄹ', 'ㄴ', 'ㅁ', 'ㄷ']
# ['ㄹ', 'ㄴ', 'ㅁ', 'ㄷ']
# ['ㄹ', 'ㄴ', 'ㅁ', 'ㄷ']

# %%
d=[]
for bb in b:
    if bb in a:
        d.append(bb)
print(d)
# Out:
# ['ㄴ', 'ㄷ']

# %%
e = [bb for bb in b if bb in a]
e
# Out:
# ['ㄴ', 'ㄷ']
