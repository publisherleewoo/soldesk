# %%
# %pip install jamo

# 클이라는 글자를 sentence.find("ㅋ") 이런식으로 찾을 수 없기때문에, 자음&모음 = 자모 라이브러리로 찾는다
# Out:
# Collecting jamo
#   Using cached jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Using cached jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Installing collected packages: jamo
# Successfully installed jamo-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# 1. 파일이 있는 실제 경로를 복사해서 넣어주세요
target_path = "/mnt/batch/tasks/shared/LS_root/mounts/clusters/testcom0208/code/Users/student02_08/Jan23_1_Text_Kor"

# 2. 해당 경로로 작업 디렉토리 변경
os.chdir(target_path)

# 3. 변경된 경로 확인
print("변경된 현재 경로:", os.getcwd())
# Out:
# 변경된 현재 경로: /mnt/batch/tasks/shared/LS_root/mounts/clusters/testcom0208/code/Users/student02_08/Jan23_1_Text_Kor

# %%
from jamo.jamo import h2j,j2hcj

b="흙"
c =h2j(b)

print(c)
# Out:
# 흙

# %%
d = j2hcj(c)
print(d)
# Out:
# ㅎㅡㄺ

# %%
# hangul-utils 깃허브  https://github.com/kaniblu/hangul-utils
# unicode.py만 프로젝트에 
 

from unicode import join_jamos

# %%
d = "ㅎㅏㅂ"
f = join_jamos(d)
print(f)
# Out:
# 합
