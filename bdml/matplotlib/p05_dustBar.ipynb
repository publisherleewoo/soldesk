# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.font_manager as fm

font_path = 'C:/Windows/Fonts/malgun.ttf' 
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_csv(
    "../numpy/seoulDust.csv", names=["날짜", "권역", "구", "미세", "초미세", "정도"]
)

data1 = df['미세']
data2 = df['초미세']
labels = df["구"]
plt.figure(figsize=(20, 6))
plt.bar(labels, data1, bottom=data2, label='미세')
plt.bar(labels, data2, label='초미세')

plt.legend()

# %%
data = [28, 1, 10]
label = ["901", "903", "902"]
e = [0, 0, 0.3]
w = {"width": 0.7, "edgecolor": "black", "linewidth": 3}
plt.pie(data, labels=label, autopct="%.1f%%", startangle=45, explode=e, wedgeprops=w)
# Out:
# ([<matplotlib.patches.Wedge at 0x24a8498dee0>,
# ...
#  [Text(-1.0944283324885935, 0.11057407040638785, '901'),
#   Text(0.6783910045880037, -0.8659016369623511, '903'),
#   Text(1.3997161297576874, -0.028191418839084877, '902')],
#  [Text(-0.5969609086301418, 0.06031312931257518, '71.8%'),
#   Text(0.370031457048002, -0.472309983797646, '2.6%'),
#   Text(0.8998175119870848, -0.018123054967983134, '25.6%')])

# %%
df = pd.read_csv(
    "../pandas/titanic.csv"
)

# %%
 
d1 = len(df[(df["Survived"]==0) & (df["Pclass"]==1)])
d2 = len(df[(df["Survived"]==0) & (df["Pclass"]==2)])
d3 = len(df[(df["Survived"]==0) & (df["Pclass"]==3)])

data = [d3,d1,d2]
labels = df["Pclass"].unique()
 
w = {"width": 0.7, "edgecolor": "black", "linewidth": 3}

plt.pie(data, labels=labels, autopct="%.2f%%", startangle=45,   wedgeprops=w)
# Out:
# ([<matplotlib.patches.Wedge at 0x24a86ce9ee0>,
# ...
#  [Text(-1.0716652915989557, 0.2480594742841431, '3'),
#   Text(0.7800398838222766, -0.7755886665279021, '1'),
#   Text(1.0709511368268392, 0.2511247947322229, '2')],
#  [Text(-0.5845447045085213, 0.13530516779135077, '67.76%'),
#   Text(0.4254763002666963, -0.4230483635606738, '14.57%'),
#   Text(0.5841551655419122, 0.13697716076303065, '17.67%')])
