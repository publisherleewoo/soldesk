# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xData = np.array([10,20,30,40,50,])
yData = [22,56,2,10,3]   # 쌩 list ->np.array로 알아서 바꿔짐

# %%
plt.plot(yData)
plt.show()

# %%
import matplotlib.font_manager as fm
font_path = 'C:/Windows/Fonts/malgun.ttf' 
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

plt.plot(xData)
plt.plot(yData)
plt.xlabel('엑스축')
plt.ylabel('와이축')
# Out:
# Text(0, 0.5, '와이축')

# %%
d ={"fontsize":20,'fontweight':900,'color':'red'}
plt.plot(xData)
plt.plot(yData)
plt.title('제목')
plt.title('제목2',loc='left')
plt.title('제목3',loc='right',fontdict=d)
# Out:
# Text(1.0, 1.0, '제목3')

# %%
plt.plot(xData,yData,"c:p")

# %%
plt.plot(xData,yData,color="#43a047", linestyle="-.", marker="X", linewidth=5)
