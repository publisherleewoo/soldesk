# %%
import pandas as pd

df = pd.read_csv('./titanic.csv')
df['Age2'] = df['Age'].fillna(900)
df['Age2'] = df['Age2'].apply(lambda age : '%d0대' %( age//10))
df['Age2'] = df['Age2'].replace('900대','미상')


#등급별 평균요금   
# df.groupby('Pclass')['Fare'].mean()
#등급별 산/죽은 사람 수
# df.groupby(['Pclass','Survived'])['PassengerId'].count()
#성별별 산/죽은 사람 수
# df.groupby(['Sex','Survived'])['PassengerId'].count()
#나이대별 ->성별별 산/죽은사람 수
# df.groupby(['Age2','Sex','Survived'])['PassengerId'].count()

# %%
#객실 뭐뭐있나 (중복제거)
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
#객식 몇개 (중복제거해서 몇개)
df["Cabin"].nunique()
# Out:
# 147

# %%
# 객실별 몇명씩
df["Cabin"].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df2 = pd.read_csv('./lnps 1.csv',names=['시장','물품','가격','날짜','시장타입','구'])
df2
# Out:
#             시장             물품    가격          날짜  시장타입    구
# 0       남부골목시장  쌀(이천쌀) 4kg 1포     0  2026-01-13  전통시장  강서구
# 1        새마을시장  바디워시 900ml 1개  4980  2026-01-13  전통시장  송파구
# 2        새마을시장    샴푸 600ml 1통     0  2026-01-13  전통시장  송파구
# 3        새마을시장      칫솔 5개 2묶음     0  2026-01-13  전통시장  송파구
# 4        새마을시장     치약 125g 1개  2437  2026-01-13  전통시장  송파구
# ...        ...            ...   ...         ...   ...  ...
# 759475    도곡시장            애호박  2380  2018-01-28  전통시장  강남구
# 759476    도곡시장        오이(다다기)   840  2018-01-28  전통시장  강남구
# 759477    도곡시장             상추  1280  2018-01-28  전통시장  강남구
# 759478    도곡시장             양파  3850  2018-01-28  전통시장  강남구
# 759479    도곡시장         무(1kg)  1780  2018-01-28  전통시장  강남구
#
# [759480 rows x 6 columns]

# %%
#시장이 뭐뭐있나
# df2['시장'].unique()
# df2['시장'].nunique()
df2['구'].value_counts()
# Out:
# 구
# 중구      41776
# 관악구     41005
# 강북구     36049
# 영등포구    35596
# 송파구     33549
# 강서구     33348
# 도봉구     32813
# 양천구     32470
# 성동구     31221
# 광진구     31218
# 성북구     30850
# 강동구     30590
# 동대문구    30530
# 마포구     30527
# 용산구     30442
# 서대문구    30385
# 강남구     30122
# 중랑구     29232
# 구로구     29014
# 금천구     26011
# 은평구     25718
# 노원구     24638
# 동작구     23237
# 서초구     20365
# 종로구     18774
# Name: count, dtype: int64
