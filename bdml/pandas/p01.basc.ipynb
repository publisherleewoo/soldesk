# %% [markdown]
# # basic

# %%
import pandas as pd

# %%
# list 스러운것
a = pd.Series([1,123,543,213890])
a
# Out:
# 0         1
# 1       123
# 2       543
# 3    213890
# dtype: int64

# %%
a[2]
# Out:
# np.int64(543)

# %%
df = pd.DataFrame()
df["이름"]=["새우깡","양파링"]
df["가격"]=[3000,4000]
print(df)
# Out:
#     이름    가격
# 0  새우깡  3000
# 1  양파링  4000

# %%
df["이름"]  # 인덱스가 나옴
# Out:
# 0    새우깡
# 1    양파링
# Name: 이름, dtype: object

# %%
b = df.set_index(df["이름"])   # 이름필드로 인덱스로 사용함. 원본데이터에 영향 안가는걸 추구(이뮤터블) 그러므로 변수에 담아서 사용하자
b
# Out:
#       이름    가격
# 이름
# 새우깡  새우깡  3000
# 양파링  양파링  4000

# %%
b.loc["새우깡"]
# Out:
# 이름     새우깡
# 가격    3000
# Name: 새우깡, dtype: object

# %%
b.iloc[1]
# Out:
# 이름     양파링
# 가격    4000
# Name: 양파링, dtype: object

# %% [markdown]
# # make

# %%
import numpy as np

# %%
df = pd.DataFrame()
df["이름"]=["새우깡","양파링"]
df["가격"]=[3000,4000]
df
# Out:
#     이름    가격
# 0  새우깡  3000
# 1  양파링  4000

# %%
df2 = pd.DataFrame()
df2["이름"] = np.array(["홍길동","김길동"])
df2["나이"] = np.array([20,30])
df2
# Out:
#     이름  나이
# 0  홍길동  20
# 1  김길동  30

# %%
#2차원  list/np.array
c = [["홍길동",20],["김길동",30]]
# print(c)
c = pd.DataFrame(c)
# 컬럼이 안나옴
print(c)
# Out:
#      0   1
# 0  홍길동  20
# 1  김길동  30

# %%
c = [["홍길동",20],["김길동",30]]
c = pd.DataFrame(c, columns =['이름','나이'])
print(c)
# Out:
#     이름  나이
# 0  홍길동  20
# 1  김길동  30

# %%
d={
   "이름":["홍길동","김길동"],
   "나이":[20,30]
  }
d = pd.DataFrame(d)
d
# Out:
#     이름  나이
# 0  홍길동  20
# 1  김길동  30

# %%
e = [
     {'이름':'홍갈동','나이':20},
     {'이름':'김길동','나이':30},
    ]
e=  pd.DataFrame(e)
print(e)
# Out:
#     이름  나이
# 0  홍갈동  20
# 1  김길동  30
