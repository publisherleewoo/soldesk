# %%
import pandas as pd

a = pd.read_csv("./titanic.csv")
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 행,열 크기
a.shape
# Out:
# (891, 12)

# %%
#필드명 보기
a.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#앞에 몇개만 보기
a.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#뒤에 몇개만 보기
a.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
a["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
a.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
a[["Name","Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
a.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
a.iloc[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a = a.set_index(a["Name"])
a
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass  \
# Name
# ...

# %%
a.loc["Montvila, Rev. Juozas"]
# Out:
# PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# Name: Montvila, Rev. Juozas, dtype: object

# %%
a.loc["Montvila, Rev. Juozas":"Dooley, Mr. Patrick"]
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Montvila, Rev. Juozas                             887         0       2
# Graham, Miss. Margaret Edith                      888         1       1
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Behr, Mr. Karl Howell                             890         1       1
# Dooley, Mr. Patrick                               891         0       3
#
#                                                                               Name  \
# Name
# Montvila, Rev. Juozas                                        Montvila, Rev. Juozas
# Graham, Miss. Margaret Edith                          Graham, Miss. Margaret Edith
# Johnston, Miss. Catherine Helen "Carrie"  Johnston, Miss. Catherine Helen "Carrie"
# Behr, Mr. Karl Howell                                        Behr, Mr. Karl Howell
# Dooley, Mr. Patrick                                            Dooley, Mr. Patrick
#
# ...

# %%
a.loc["Montvila, Rev. Juozas"]["Age"]
# Out:
# np.float64(27.0)

# %%
a.loc["Montvila, Rev. Juozas"][["Age","Pclass"]]
# Out:
# Age       27.0
# Pclass       2
# Name: Montvila, Rev. Juozas, dtype: object

# %%
a.loc["Montvila, Rev. Juozas":"Dooley, Mr. Patrick"]["Age"]
# Out:
# Name
# Montvila, Rev. Juozas                       27.0
# Graham, Miss. Margaret Edith                19.0
# Johnston, Miss. Catherine Helen "Carrie"     NaN
# Behr, Mr. Karl Howell                       26.0
# Dooley, Mr. Patrick                         32.0
# Name: Age, dtype: float64

# %%
a["Age"]>30
# Out:
# Name
# Braund, Mr. Owen Harris                                False
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)     True
# Heikkinen, Miss. Laina                                 False
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            True
# Allen, Mr. William Henry                                True
#                                                        ...
# Montvila, Rev. Juozas                                  False
# Graham, Miss. Margaret Edith                           False
# Johnston, Miss. Catherine Helen "Carrie"               False
# Behr, Mr. Karl Howell                                  False
# Dooley, Mr. Patrick                                     True
# Name: Age, Length: 891, dtype: bool

# %%
a[a["Age"]>30]["Age"]
# Out:
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
# McCarthy, Mr. Timothy J                                54.0
# Bonnell, Miss. Elizabeth                               58.0
#                                                        ...
# Vander Cruyssen, Mr. Victor                            47.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          56.0
# Markun, Mr. Johann                                     33.0
# Rice, Mrs. William (Margaret Norton)                   39.0
# Dooley, Mr. Patrick                                    32.0
# Name: Age, Length: 305, dtype: float64

# %%
a[(20<=a["Age"]) & (a["Age"]<30)][["Name","Age","Pclass",]]
# Out:
#                                                                                                 Name  \
# Name
# Braund, Mr. Owen Harris                                                      Braund, Mr. Owen Harris
# Heikkinen, Miss. Laina                                                        Heikkinen, Miss. Laina
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Saundercock, Mr. William Henry                                        Saundercock, Mr. William Henry
# Sloper, Mr. William Thompson                                            Sloper, Mr. William Thompson
# ...                                                                                              ...
# Dahlberg, Miss. Gerda Ulrika                                            Dahlberg, Miss. Gerda Ulrika
# Banfield, Mr. Frederick James                                          Banfield, Mr. Frederick James
# ...
